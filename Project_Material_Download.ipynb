# %% [markdown]
# <a href="https://colab.research.google.com/github/Jarrod-Street/Jarrod-Street/blob/main/Project_Material_Download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()   # upload kaggle.json here
# Out:
#      <input type="file" id="files-13196d38-01b1-4e92-a608-e8c8756d527c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-13196d38-01b1-4e92-a608-e8c8756d527c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download -d mlg-ulb/creditcardfraud
# !unzip creditcardfraud.zip

# !kaggle datasets download -d blastchar/telco-customer-churn
# !unzip telco-customer-churn.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
# License(s): DbCL-1.0
# ...
#   0% 0.00/66.0M [00:00<?, ?B/s]
# 100% 66.0M/66.0M [00:00<00:00, 1.50GB/s]
# Archive:  creditcardfraud.zip
#   inflating: creditcard.csv
# Dataset URL: https://www.kaggle.com/datasets/blastchar/telco-customer-churn
# License(s): copyright-authors
# ...
#   0% 0.00/172k [00:00<?, ?B/s]
# 100% 172k/172k [00:00<00:00, 476MB/s]
# Archive:  telco-customer-churn.zip
#   inflating: WA_Fn-UseC_-Telco-Customer-Churn.csv

# %%
import pandas as pd

# Fraud dataset
df_fraud = pd.read_csv("creditcard.csv")
print(df_fraud.head())

# Churn dataset
df_churn = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")
print(df_churn.head())
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...
